# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv("lavin_results/meanshift_all_no_seeding.csv")
del df['Unnamed: 0']

# %%
df_sorted = df.sort_values(by="group_label")
df_sorted
# Out:
#      docid  group_label                                        genres  year
# 983    984            0                            teamred | chiscifi  1989
# 574    575            0                           chirandom | teamred  1931
# 575    576            0             chifantasy | teamblack | chiscifi  1931
# 576    577            0                          teamblack | chiscifi  1931
# 577    578            0                            teamred | chiscifi  1931
# 578    579            0               chirandom | teamblack | chimyst  1931
# 579    580            0                          teamblack | chiscifi  1931
# 580    581            0                    teamblack | chimyst | stew  1931
# 581    582            0                         chirandom | teamblack  1931
# 582    583            0                    teamblack | chimyst | stew  1932
# 583    584            0                            teamred | chiscifi  1932
# ...

# %%
genres_piped = list(df_sorted["genres"])
genres_main = []
for i in genres_piped:
    gen = i.split(" | ")
    g = []
    for z in gen:
        if "lavin" in z:
            g.append(z)
            break
        elif z != "teamred" and z!= "teamblack" and z!= "stew" and "random" not in z:
            g.append(z)
    if len(g) > 1:
        g = ["multi",]
    if len(g) == 0:
        g = ["non_genre"]
    genres_main.append(g)
df_sorted["final_genre"] = [i[0] for i in genres_main]

# %%
#group_clusters = zip(list(df_sorted["group_label"]), 
#list(group_clusters)
df_sorted
# Out:
#      docid  group_label                                        genres  year  \
# 983    984            0                            teamred | chiscifi  1989
# 574    575            0                           chirandom | teamred  1931
# 575    576            0             chifantasy | teamblack | chiscifi  1931
# 576    577            0                          teamblack | chiscifi  1931
# 577    578            0                            teamred | chiscifi  1931
# 578    579            0               chirandom | teamblack | chimyst  1931
# 579    580            0                          teamblack | chiscifi  1931
# 580    581            0                    teamblack | chimyst | stew  1931
# 581    582            0                         chirandom | teamblack  1931
# 582    583            0                    teamblack | chimyst | stew  1932
# 583    584            0                            teamred | chiscifi  1932
# ...

# %%
genre_distill = {'anatscifi':'scifi',
 'blcrime',
 'chifantasy',
 'chihorror',
 'chimyst',
 'chirandom',
 'chiscifi',
 'chiutopia',
 'cozy',
 'crime',
 'det100',
 'drop',
 'femscifi',
 'hardboiled',
 'juvenile',
 'lavin_deranged',
 'lavin_ghost',
 'lavin_magic',
 'lavin_slasher',
 'locdetective',
 'locdetmyst',
 'locghost',
 'lochorror',
 'lockandkey',
 'locscifi',
 'newgate',
 'pbgothic',
 'random',
 'sensation',
 'stangothic',
 'supernatural'}
