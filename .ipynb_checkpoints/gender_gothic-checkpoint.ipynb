# %%
import pandas as pd

# %%
df1 = pd.read_csv("female_gothic_data/male_list_all_retrieved_texts.csv")
df2 = pd.read_csv("female_gothic_data/female_list_all_retrieved_texts.csv")
list(df1)
# Out:
# ['\ufeffid',
#  'source',
#  'source_date_accessed',
#  'source_id',
#  'short_title',
#  'author',
#  'year',
#  'genre',
#  'gender',
#  'translator',
#  'title',
#  'publication',
#  'format',
#  'catalogue_numbers',
#  'notes',
#  'further_editions',
#  'riddell',
#  'gutenberg',
#  'underwood']

# %%
#for each row, check if underwood
df1_underwood = df1.loc[df1['underwood'] == 'x']
df2_underwood = df2.loc[df1['underwood'] == 'x']
#check if only riddell
df1_riddell = df1.loc[df1['underwood'] != 'x']
df1_riddell = df1_riddell.loc[df1_riddell['riddell'] == 'x']
df2_riddell = df2.loc[df2['underwood'] != 'x']
df2_riddell = df2_riddell.loc[df2_riddell['riddell'] == 'x']
#if yes, get txt by id column from female_gothic_txt and male_gothic_txt

#add a column for the riddell id so there's no chance of overlap with other id sets 
df1_riddell['rid'] = ["r_"+str(i) for i in list(df1_riddell['\ufeffid'])]
df2_riddell['rid'] = ["r_"+str(i) for i in list(df2_riddell['\ufeffid'])]

#check if matched in gutenberg only
df1_gutenberg = df1.loc[df1['underwood'] != 'x']
df1_gutenberg = df1_gutenberg.loc[df1_gutenberg['riddell'] != 'x']

df2_gutenberg = df2.loc[df2['underwood'] != 'x']
df2_gutenberg = df2_gutenberg.loc[df2_gutenberg['riddell'] != 'x']

#if yes, title match in gutenberg id male_gothic_matches_filtered, female_gothic_matches_filtered
gut_match_1 = pd.read_csv("female_gothic_data/male_gothic_matches_filtered.csv")
gut_match_2 = pd.read_csv("female_gothic_data/female_gothic_matches_filtered.csv")
#read more than one match as multivolume

# %%
#convert each df to a list of dicts in id order, join with existing lists, genre_
"""
_ids, dates, genres, authors, titles, big_genres, lavin_genres, processed_genres 
"""
#big_genres value = important
#append columns to pData attributes
#append dictionaries to feature_dicts_full
#remove all underwood biggenre = gothic

# %%
#get txt files for all gutenberg_match files
#0 = gut_id
#1 = title len 25
# url is structured like this http://www.gutenberg.org/cache/epub/[id]/pg[id].txt
#if yes, title match in gutenberg id male_gothic_matches_filtered, female_gothic_matches_filtered
gut_match_1 = pd.read_csv("female_gothic_data/male_gothic_matches_filtered.csv")
gut_match_2 = pd.read_csv("female_gothic_data/female_gothic_matches_filtered.csv")
import requests
def get_gut(idlist, folder):
    base_url = "http://www.gutenberg.org/cache/epub/"
    #[id]/pg[id].txt
    for gid in idlist:
        gids = str(gid)
        gut_url = base_url + gids +"/pg" + gids + ".txt"
        gut = requests.get(gut_url)
        gtxt = gut.text
        filename = folder + "/g_" + gids + ".txt"
        with open(filename, "a") as f:
            f.write(gtxt)
        f.close()
#run function on id lists, folders
get_gut(list(gut_match_1['0']), "female_gothic_data/male_gothic_txt")
get_gut(list(gut_match_2['0']), "female_gothic_data/female_gothic_txt")
#done!

# %%
from random import shuffle
from application.selective_features import make_feature_list, dictionaries_of_features, make_genres_big_and_lavin
from application.pickles import pickledData
import pandas as pd
from scipy.stats.stats import spearmanr
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.metrics import recall_score

# all this has to do is split a list of ids into three groups
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

def divide_by_three(list_of_ids):
    destinations = []
    while len(list_of_ids) > 2 or len(list_of_pairs) % 3 == 0:
        #grab a random id from big_genre and remove
        for m, l in enumerate(destinations):

            candidates = list(list_of_pairs.keys())
            shuffle(candidates)
            key = candidates[0]
            #print(key)
            candidate = list_of_pairs[key]
            #remove from dictionary
            del list_of_pairs[key]
            #make sure the author is not in the dict
            if candidate not in l:
                l[key] = candidate

            else:
                next_one = destinations[m+1]
                #next list same id if author in dict
                if candidate not in next_one:
                    next_one[key] = candidate
                else:
                    next_one = destinations[m+2]
                    if candidate not in next_one:
                        next_one[key] = candidate
    destinations_trimmed =[]
    for i,j in enumerate(destinations):
        aTuple = list(j.items())
        shuffle(aTuple)
        destinations_trimmed.append(dict(aTuple[:83]))
    return destinations_trimmed

def divide_list(mylist, number_of_splits):
    def chunks(l, n):
        """Yield successive n-sized chunks from l."""
        for i in range(0, len(l), n):
            yield l[i:i + n]

    l = (len(mylist) % number_of_splits)
    a = len(mylist) - l
    b = int(a/number_of_splits)
    newlists = list(chunks(mylist, b))
    newlists = [i for i in newlists if len(i) == b]
    return newlists

#this will be moved to application folder
def partition_test_train(genre, df, number_of_partitions):
    # supply a genre
    df_genre = df.loc[df['big_genres'] == genre]
    df_non_genre = df.loc[df['big_genres'] != genre ]
    df_non_genre = df_non_genre.loc[df_non_genre['big_genres'] != "multi" ]
    # create a dataset of random ids 50% in genre, 50% out of genre
    genre_ids = list(df_genre['ids'])
    # split into three separate sets of ids
    genre_split = divide_list(genre_ids, number_of_partitions)

    non_genre_ids = list(df_non_genre['ids'])
    #shuffle non_genre before splitting
    shuffle(non_genre_ids)
    non_genre_ids = non_genre_ids[0:len(genre_ids)]
    # split into three separate sets of ids
    non_genre_split = divide_list(non_genre_ids, number_of_partitions)

    rejoined = []
    #rejoin genre and nongenre

    for i, j in enumerate(non_genre_split):
        joined = j + genre_split[i]
        rejoined.append(joined)
    #sort by id and convert rejoined back to full df
    for r in rejoined:
        r.sort()
    rejoined_dfs = []
    for i in rejoined:
        new_df = df.loc[df['ids'].isin(i)]
        rejoined_dfs.append(new_df)
    return rejoined_dfs, rejoined

pData = pickledData()

# import feature dictionaries
feature_dicts_full = pData.feature_dicts

photo_terms = make_feature_list("lavin_lexicon/photo_terms.csv", "score", 8)

#perform feature selection on dictionaries of term frequencies, using top 100 photo_terms
feature_dicts = dictionaries_of_features(feature_dicts_full, photo_terms)

#define a dictionary with ids, genres, dates, authors, etc. Pass to each function
metadata = {"ids": pData._ids, "dates": pData.dates, "genres":pData.genres, "authors":pData.authors,
                "titles":pData.titles,"big_genres":pData.big_genres, "lavin_genres":pData.lavin_genres}

#convert all metadata to dataframe
data = [metadata[i] for i in metadata.keys()]
df = pd.DataFrame(data)
df = df.transpose()
df.index.name = 'position'
df.columns=metadata.keys()

df1 = pd.read_csv("female_gothic_data/male_list_all_retrieved_texts.csv")
df2 = pd.read_csv("female_gothic_data/female_list_all_retrieved_texts.csv")

#for each row, get underwood matches
df1_underwood = df1.loc[df1['underwood'] == 'x']
df2_underwood = df2.loc[df2['underwood'] == 'x']

#check if only riddell or gutenberg (if both, use riddell)
df1_riddell = df1.loc[df1['underwood'] != 'x']
df1_riddell = df1_riddell.loc[df1_riddell['riddell'] == 'x']

df2_riddell = df2.loc[df2['underwood'] != 'x']
df2_riddell = df2_riddell.loc[df2_riddell['riddell'] == 'x']

#add a column for the riddell id so there's no chance of overlap with other id sets
df1_riddell['rid'] = ["r_"+str(i) for i in list(df1_riddell['\ufeffid'])]
df2_riddell['rid'] = ["r_"+str(i) for i in list(df2_riddell['\ufeffid'])]

#check if matched in gutenberg only
df1_gutenberg = df1.loc[df1['underwood'] != 'x']
df1_gutenberg = df1_gutenberg.loc[df1_gutenberg['riddell'] != 'x']

df2_gutenberg = df2.loc[df2['underwood'] != 'x']
df2_gutenberg = df2_gutenberg.loc[df2_gutenberg['riddell'] != 'x']

#add a column for the gutenberg id so there's no chance of overlap with other id sets
df1_gutenberg['gid'] = ["g_"+str(i) for i in list(df1_gutenberg['\ufeffid'])]

df2_gutenberg['gid'] = ["g_"+str(i) for i in list(df2_gutenberg['\ufeffid'])]

#convert each df to a list of dicts in id order, join with existing lists
"""
_ids, dates, genres, authors, titles, big_genres, lavin_genres, processed_genres
"""
#big_genres value = important
#append columns to pData attributes
#append dictionaries to feature_dicts_full

def for_append_metadata(df, id_column, gender, metadata):
    _ids = list(df[id_column])
    dates = list(df["year"])
    genres = ["gothic" for i in _ids]
    authors = list(df["author"])
    titles = list(df["title"])
    big_genres = [gender + "_gothic" for i in _ids]
    lavin_genres = ["gothic" for i in _ids]
    columns = [titles, lavin_genres, big_genres, _ids, authors, genres, dates]
    df = pd.DataFrame(columns)
    df = df.transpose()
    df.columns=metadata.keys()
    df.index.name = 'position'
    
    return df

df_ = for_append_metadata(df1_riddell, 'rid', "male", metadata)
df = df.append(df_)
df_ = for_append_metadata(df1_gutenberg, 'gid', "male", metadata)
df = df.append(df_)
df_ = for_append_metadata(df1_underwood, '\ufeffid', "male", metadata)
df = df.append(df_)
df_ = for_append_metadata(df1_gutenberg, 'gid', "female", metadata)
df = df.append(df_)
df_ = for_append_metadata(df2_riddell, 'rid', "female", metadata)
df = df.append(df_)
df_ = for_append_metadata(df2_underwood, '\ufeffid', "female", metadata)
df = df.append(df_)
# Out:
# Loaded pickle data successfully.

# %%
df = df.loc[df["big_genres"] != "gothic"]
df
# Out:
#                                                      titles  lavin_genres  \
# position
# 0                                     The+savages+of+Europe  no_lavin_tag
# 1                               Eloisa%3A+or+A+series+of+or  no_lavin_tag
# 2                               The+memoirs+of+Miss+D%27Arv  no_lavin_tag
# 4                                 Memoirs+of+the+year+two+t  no_lavin_tag
# 5                                 Letters+from+Henrietta+to  no_lavin_tag
# 7                              Letters+of+Madame+Du+Montier  no_lavin_tag
# 8                                The+new+Robinson+Crusoe%3B  no_lavin_tag
# 9                                    Tales+of+the+castle%3B  no_lavin_tag
# 11                 Anna%3B+or%2C+Memoirs+of+a+Welch+Heiress  no_lavin_tag
# 13                              Heloise%3A+or+The+siege+of+  no_lavin_tag
# 16                                The+adventures+of+John+of  no_lavin_tag
# 18                                The+negro+equalled+by+few  no_lavin_tag
# 20                                The+devil+upon+two+sticks  no_lavin_tag
# 24                                            Turkish+tales  no_lavin_tag
# 25                        Ellen%2C+Countess+of+Castle+Howel  no_lavin_tag
# 28                                          Memoirs+of+Mary  no_lavin_tag
# 29                                                    Henry  no_lavin_tag
# 32                            Camilla%3A+or%2C+A+picture+of  no_lavin_tag
# 36                                         The+false+friend  no_lavin_tag
# 37                           Memoirs+of+modern+philosophers  no_lavin_tag
# 38                                            Russian+tales  no_lavin_tag
# 39                                                Devasmita  no_lavin_tag
# 40                                       The+Three+Sharpers  no_lavin_tag
# 41                                              Old+Nick%3B  no_lavin_tag
# 42                                              Old+Nick%3B  no_lavin_tag
# 45                                                     Home  no_lavin_tag
# 46                               Letters+of+Miss+Riversdale  no_lavin_tag
# 49        Barbara+Markham%3B+or%2C+The+profligate+requit...  no_lavin_tag
# 51                                         Canterbury+tales  no_lavin_tag
# 55                                      Madame+de+Maintenon  no_lavin_tag
# ...                                                     ...           ...
# 35        THE MAGIC RING; A ROMANCE, FROM THE GERMAN OF ...        gothic
# 36        THE LAST OF THE MOHICANS; A NARRATIVE OF 1757....        gothic
# 37                                              VIVIAN GREY        gothic
# 38        THE RED ROVER, A TALE. BY THE AUTHOR OF "THE S...        gothic
# 39                   THE EPICUREAN, A TALE. BY THOMAS MOORE        gothic
# 40        CHRONICLES OF THE CANONGATE; BY THE AUTHOR OF ...        gothic
# 41        THE VOYAGE OF CAPTAIN POPANILLA. BY THE AUTHOR...        gothic
# 42        THE LIFE OF MANSIE WAUCH, TAILOR IN DALKEITH. ...        gothic
# 43        THE ADVENTURES OF HAJJI BABA, OF ISPAHAN, IN E...        gothic
# 44        DEVEREUX. A TALE. BY THE AUTHOR OF "PELHAM." I...        gothic
# 45        THE DISOWNED. BY THE AUTHOR OF "PELHAM." IN FO...        gothic
# 46            RICHELIEU, A TALE OF FRANCE. IN THREE VOLUMES        gothic
# 47        ANNE OF GEIERSTEIN; OR, THE MAIDEN OF THE MIST...        gothic
# 48                                                      NaN        gothic
# 0         CASTLE RACKRENT, AN HIBERNIAN TALE. TAKEN FROM...        gothic
# 1         ZOFLOYA; OR, THE MOOR: A ROMANCE OF THE FIFTEE...        gothic
# 2         ZULMA, AND OTHER TALES: TO WHICH IS PREFIXED A...        gothic
# 3         EDRIC, THE FORESTER: OR, THE MYSTERIES OF THE ...        gothic
# 4         THE SPECTRE OF LANMERE ABBEY, OR THE MYSTERY O...        gothic
# 5         ELEANOR; OR, THE SPECTRE OF ST. MICHAEL'S. A R...        gothic
# 6         THE FORGED NOTE: OR, JULIAN AND MARIANNE. A MO...        gothic
# 7         THE TRADITION OF THE CASTLE; OR, SCENES IN THE...        gothic
# 8         TALES OF THE PEERAGE AND PEASANTRY. EDITED BY ...        gothic
# 9         THE ITALIAN, OR THE CONFESSIONAL OF THE BLACK ...        gothic
# 10        THE OLD MANOR HOUSE. A NOVEL, IN FOUR VOLUMES....        gothic
# 0         FRANKENSTEIN; OR, THE MODERN PROMETHEUS. IN TH...        gothic
# 1         EMMELINE, THE ORPHAN OF THE CASTLE. BY CHARLOT...        gothic
# 2         THE MYSTERIES OF UDOLPHO, A ROMANCE; INTERSPER...        gothic
# 3         THE ROMANCE OF THE FOREST: INTERSPERSED WITH S...        gothic
# 4         A SICILIAN ROMANCE. BY THE AUTHORESS OF THE CA...        gothic
#
#              big_genres     ids  \
# position
# 0             non_genre       1
# 1             non_genre       2
# 2             non_genre       3
# 4                 scifi       5
# 5             non_genre       6
# 7             non_genre       8
# 8             non_genre       9
# 9             non_genre      10
# 11            non_genre      12
# 13            non_genre      14
# 16            non_genre      17
# 18            non_genre      19
# 20            non_genre      21
# 24            non_genre      25
# 25            non_genre      26
# 28            non_genre      29
# 29            non_genre      30
# 32            non_genre      33
# 36            non_genre      37
# 37            non_genre      38
# 38            non_genre      39
# 39                crime      40
# 40                crime      41
# 41            non_genre      42
# 42            non_genre      43
# 45            non_genre      46
# 46            non_genre      47
# 49            non_genre      50
# 51            non_genre      52
# 55            non_genre      56
# ...                 ...     ...
# 35        female_gothic  g_1887
# 36        female_gothic  g_1973
# 37        female_gothic  g_1978
# 38        female_gothic  g_2052
# 39        female_gothic  g_2080
# 40        female_gothic  g_2088
# 41        female_gothic  g_2145
# 42        female_gothic  g_2163
# 43        female_gothic  g_2165
# 44        female_gothic  g_2211
# 45        female_gothic  g_2212
# 46        female_gothic  g_2239
# 47        female_gothic  g_2264
# 48        female_gothic  g_2510
# 0         female_gothic    r_29
# 1         female_gothic   r_470
# 2         female_gothic  r_1074
# 3         female_gothic  r_1291
# 4         female_gothic  r_1515
# 5         female_gothic  r_1558
# 6         female_gothic  r_1815
# 7         female_gothic  r_1840
# 8         female_gothic  r_2795
# 9         female_gothic  r_3008
# 10        female_gothic  r_3009
# 0         female_gothic    1367
# 1         female_gothic    3002
# 2         female_gothic    3004
# 3         female_gothic    3005
# 4         female_gothic    3003
#
#                                                     authors  \
# position
# 0                               Lesuire%2C+Robert+Martin%2C
# 1                               Rousseau%2C+Jean-Jacques%2C
# 2                                                Anonymous4
# 4                              Mercier%2C+Louis-Sbastien%2C
# 5                                                Henrietta.
# 7                                   Leprince+de+Beaumont%2C
# 8                              Campe%2C+Joachim+Heinrich%2C
# 9                                 Genlis%2C+Stphanie+Flicit
# 11                                 Bennett%2C+Anna+Maria%2C
# 13                              Berkeley%2C+George+Monck%2C
# 16                                        White%2C+James%2C
# 18                                     Lavalle%2C+Joseph%2C
# 20                                      Combe%2C+William%2C
# 24                                       Moser%2C+Joseph%2C
# 25                                 Bennett%2C+Anna+Maria%2C
# 28                                               Gunning%2C
# 29                                 Cumberland%2C+Richard%2C
# 32                                       Burney%2C+Fanny%2C
# 36                                Robinson%2C+Mary+Darby%2C
# 37                                 Hamilton%2C+Elizabeth%2C
# 38                        Karamzin%2C+Nikola+Mikhalovich%2C
# 39                                               Anonymous5
# 40                                               Anonymous8
# 41                                     Du+Bois%2C+Edward%2C
# 42                                     Du+Bois%2C+Edward%2C
# 45                                      Cullen%2C+Margaret.
# 46                                               Anonymous0
# 49                                               Anonymous7
# 51                                        Lee%2C+Harriet%2C
# 55                             Genlis%2C+Stphanie+Flicit%2C
# ...                                                     ...
# 35        Friedrich Heinrich Karl, Baron de la Motte FOU...
# 36                                    James Fenimore COOPER
# 37                  Benjamin, Earl of Beaconsfield DISRAELI
# 38                                    James Fenimore COOPER
# 39                                             Thomas MOORE
# 40                                         Sir Walter SCOTT
# 41                  Benjamin, Earl of Beaconsfield DISRAELI
# 42                                       David Macbeth MOIR
# 43                                   James Justinian MORIER
# 44                              Edward George BULWER LYTTON
# 45                              Edward George BULWER LYTTON
# 46                             George Payne Rainsford JAMES
# 47                                         Sir Walter SCOTT
# 48                                       MARRYAT, Frederick
# 0                                           Maria EDGEWORTH
# 1                                           Charlotte DACRE
# 2               Anne Louise Germaine de STA&#203;L-HOLSTEIN
# 3                                                  Anne KER
# 4                                  Sarah Scudgell WILKINSON
# 5         Miss C. D. HAYNES [afterwards GOLLAND, Mrs C. D.]
# 6                                        Hannah Maria JONES
# 7                                        Regina Maria ROCHE
# 8         [SULLIVAN, Arabella Jane]; DACRE, Lady [Barbar...
# 9                                            RADCLIFFE, Ann
# 10                                         SMITH, Charlotte
# 0                               Mary Wollstonecraft SHELLEY
# 1                                          SMITH, Charlotte
# 2                                            RADCLIFFE, Ann
# 3                                          [RADCLIFFE, Ann]
# 4                                          [RADCLIFFE, Ann]
#
#                                genres dates
# position
# 0                    teamred | random  1760
# 1                    teamred | random  1761
# 2                  teamblack | random  1764
# 4               teamblack | anatscifi  1771
# 5                  teamblack | random  1777
# 7                  teamblack | random  1780
# 8                  teamblack | random  1780
# 9                    teamred | random  1785
# 11                   teamred | random  1786
# 13                   teamred | random  1788
# 16                 teamblack | random  1790
# 18                 teamblack | random  1790
# 20                 teamblack | random  1791
# 24                   teamred | random  1794
# 25                   teamred | random  1794
# 28                 teamblack | random  1794
# 29                   teamred | random  1795
# 32                 teamblack | random  1796
# 36                   teamred | random  1799
# 37                   teamred | random  1800
# 38                   teamred | random  1800
# 39             lockandkey | teamblack  1800
# 40        teamred | lockandkey | stew  1800
# 41                   teamred | random  1801
# 42                   teamred | random  1801
# 45                   teamred | random  1802
# 46                 teamblack | random  1803
# 49                 teamblack | random  1803
# 51                   teamred | random  1803
# 55                   teamred | random  1806
# ...                               ...   ...
# 35                             gothic  1825
# 36                             gothic  1826
# 37                             gothic  1826
# 38                             gothic  1827
# 39                             gothic  1827
# 40                             gothic  1827
# 41                             gothic  1828
# 42                             gothic  1828
# 43                             gothic  1828
# 44                             gothic  1829
# 45                             gothic  1829
# 46                             gothic  1829
# 47                             gothic  1829
# 48                             gothic   NaN
# 0                              gothic  1800
# 1                              gothic  1806
# 2                              gothic  1813
# 3                              gothic  1817
# 4                              gothic  1820
# 5                              gothic  1821
# 6                              gothic  1824
# 7                              gothic  1824
# 8                              gothic  1835
# 9                              gothic  1797
# 10                             gothic  1793
# 0                              gothic  1818
# 1                              gothic  1788
# 2                              gothic  1794
# 3                              gothic  1791
# 4                              gothic  1790
#
# [970 rows x 7 columns]

# %%
metadata.keys()
# Out:
# dict_keys(['titles', 'lavin_genres', 'big_genres', 'ids', 'authors', 'genres', 'dates'])

# %%
culled_dicts = []
df_originals = df.loc[df['big_genres'] != 'female_gothic']
df_originals = df_originals.loc[df_originals['big_genres'] != 'male_gothic']
df_culled = list(df_originals['ids'])
for h,i in enumerate(pData._ids):
    if i in df_culled:
        culled_dicts.append(feature_dicts_full[h])

# %%
for h,i in enumerate(df['ids']):
    try:
        if "g" in i:
            print(i)

        if "r" in i:
            print(i)
    except:
        pass

# %%
g_ids = list(gut_match_1['0'])
g_titles = list(gut_match_1['1'])

# %%
#merge multivolume together, title:list_of_ids even if just one id
merged = {}
for t in titles:
# Out:
# ['ormond; or, the secret wi',
#  'ormond; or, the secret wi',
#  'ormond; or, the secret wi',
#  'arthur mervyn; or, memoir',
#  'edgar huntly; or, memoirs',
#  'Jane Talbot',
#  'Falkland, Book 1.',
#  'Devereux — Complete',
#  'The Disowned — Complete',
#  'Peter Schlemihl',
#  'Peter Schlemihl',
#  'the last of the mohicans;',
#  'the last of the mohicans:',
#  'Vivian Grey',
#  'the voyage of captain pop',
#  'The Young Duke',
#  'Undine',
#  'Undine',
#  'Undine',
#  'sintram and his companion',
#  'the magic ring and other ',
#  'the annals of the parish:',
#  'the ayrshire legatees; or',
#  'The Provost',
#  'ringan gilhaize, or, the ',
#  'Hermann and Dorothea',
#  'Hermann und Dorothea',
#  "wilhelm meister's apprent",
#  "the devil's elixir, vol. ",
#  "the devil's elixir, vol. ",
#  'the brownie of bodsbeck, ',
#  'the brownie of bodsbeck, ',
#  'the three perils of man; ',
#  'the three perils of man; ',
#  'the three perils of man; ',
#  'the private memoirs and c',
#  'Bracebridge Hall',
#  'Tales of a Traveller',
#  'richelieu: a tale of fran',
#  'richelieu: a tale of fran',
#  'richelieu: a tale of fran',
#  'Newton Forster',
#  'the life of mansie wauch:',
#  'the life of mansie wauch:',
#  'The Vampyre; a Tale',
#  'Waverley',
#  'Guy Mannering',
#  'The Antiquary — Complete',
#  'Rob-Roy',
#  'The Abbot',
#  'Ivanhoe',
#  'Ivanhoe',
#  'Ivanhoe: A Romance',
#  'The Monastery',
#  'Kenilworth',
#  'The Fortunes of Nigel',
#  'Peveril of the Peak',
#  'Quentin Durward',
#  'Quentin Durward',
#  'Qventin Durward',
#  "St. Ronan's Well",
#  'chronicles of the canonga',
#  'anne of geierstein, volum',
#  'anne of geierstein: (volu',
#  'The Red Rover: A Tale',
#  'the adventures of hajji b',
#  'the adventures of hajji b',
#  'Nightmare Abbey',
#  'The Epicurean',
#  'The Necromancers']
