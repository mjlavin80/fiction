# %%
# %matplotlib inline
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
def confusion_from_csv(csv, genre_type):
    import pandas as pd
    df = pd.read_csv(csv)
    
    #depending on genre_type, get cluster index and appropriate genre
    if genre_type == "lavin":
        genres = list(df["lavin_genres"])
    else:
        genres = list(df["big_genres"])
    
    clusters = [str(i) for i in list(df["labels"])]
     
    y_actu = pd.Series(genres, name='Human Coded')
    y_pred = pd.Series(clusters, name='Inferred')
    
    df_confusion = pd.crosstab(y_pred, y_actu)
    filename = csv.replace("lavin_results/", "").replace(".csv", "_confusion_"+genre_type)
    df_confusion.to_csv("viz/"+ filename +".csv")
import glob
csvs = glob.glob("lavin_results/*.csv")
for csv in csvs:
    if "horror" not in csv:
        confusion_from_csv(csv, genre_type="big")
for csv in csvs:
    confusion_from_csv(csv, genre_type="lavin")

# %%
#get feature dicts from .p file
from application.pickles import pickledData

pData = pickledData()
_ids_dates_genres = pData.metadata
_ids = pData._ids
dates = pData.dates
genres = pData.genres
feature_dicts = pData.feature_dicts

from application.selective_features import make_feature_list, dictionaries_without_features, dictionaries_of_features

top_genre_terms = make_feature_list("lavin_lexicon/features_correlation_with_genre_all.csv", "spearman", 8500)
#print(top_genre_terms)
top_year_terms = make_feature_list("lavin_lexicon/features_correlation_with_pubdate_all.csv", "pearson", 500)
#print(top_year_terms)

#run dictionaries of features
new_feature_dicts = dictionaries_of_features(feature_dicts, top_genre_terms)
print("Done making feature list")

#run dictionaries without features
revised_feature_dicts = dictionaries_without_features(new_feature_dicts, top_year_terms)

from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import pandas as pd

# create vectors using N top features not in stops
tfidf = TfidfTransformer()
vec = DictVectorizer()
vect = vec.fit_transform(revised_feature_dicts)
adjusted = tfidf.fit_transform(vect)
data = adjusted.toarray()
print(len(data[0]))
# Out:
# Loaded pickle data successfully.
# Done making feature list
# 8040

# %%
def gs(a):
    pairs = {'crime':0, 'gothic':1, 'multi':2, 'non_genre':3, 'scifi':4, 'sensation':5}
    b = pairs[a]
    return b
def ls(a):
    pairs = {'lavin_deranged':0,'lavin_ghost':1, 'lavin_magic':2, 'lavin_multi':3, 'lavin_slasher':4,'no_lavin_tag':5}
    b=pairs[a]
    return b

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X = data
X_r = pca.fit(X).transform(X)

_df = pd.read_csv("lavin_results/mini_batch_km_all.csv")
_df["x"] = X_r[:,0] 
_df["y"] = X_r[:,1]
_df['lavin_scaled'] = _df["lavin_genres"].apply(ls)
_df['genre_scaled'] = _df["big_genres"].apply(gs)
_df
# Out:
#      position  dates  ids                                             genres  \
# 0           0   1760    1                                   teamred | random
# 1           1   1761    2                                   teamred | random
# 2           2   1764    3                                 teamblack | random
# 3           3   1764    4            teamred | pbgothic | stew | lavin_ghost
# 4           4   1771    5                              teamblack | anatscifi
# 5           5   1777    6                                 teamblack | random
# 6           6   1777    7                 teamblack | pbgothic | lavin_ghost
# 7           7   1780    8                                 teamblack | random
# 8           8   1780    9                                 teamblack | random
# 9           9   1785   10                                   teamred | random
# 10         10   1785   11       teamblack | pbgothic | stew | lavin_deranged
# 11         11   1786   12                                   teamred | random
# 12         12   1786   13          teamblack | pbgothic | stew | lavin_magic
# 13         13   1788   14                                   teamred | random
# 14         14   1788   15       teamblack | pbgothic | stew | lavin_deranged
# 15         15   1788   16         teamred | pbgothic | stew | lavin_deranged
# 16         16   1790   17                                 teamblack | random
# 17         17   1790   18         teamred | pbgothic | stew | lavin_deranged
# 18         18   1790   19                                 teamblack | random
# 19         19   1790   20         teamred | pbgothic | stew | lavin_deranged
# 20         20   1791   21                                 teamblack | random
# 21         21   1791   22                             teamblack | stangothic
# 22         22   1791   23       teamblack | pbgothic | stew | lavin_deranged
# 23         23   1794   24         teamred | pbgothic | stew | lavin_deranged
# 24         24   1794   25                                   teamred | random
# 25         25   1794   26                                   teamred | random
# 26         26   1794   27                        teamblack | pbgothic | stew
# 27         27   1794   28                                 teamred | pbgothic
# 28         28   1794   29                                 teamblack | random
# 29         29   1795   30                                   teamred | random
# ..        ...    ...  ...                                                ...
# 954       954   1987  955                                  teamred | chimyst
# 955       955   1987  956                        teamblack | chiscifi | stew
# 956       956   1987  957                   chirandom | teamblack | chiscifi
# 957       957   1987  958                      chirandom | teamred | chimyst
# 958       958   1987  959                                chirandom | teamred
# 959       959   1987  960  teamred | pbgothic | chihorror | lavin_slasher...
# 960       960   1987  961                                chirandom | teamred
# 961       961   1987  962                                teamblack | chimyst
# 962       962   1987  963                             chifantasy | teamblack
# 963       963   1987  964                 teamblack | pbgothic | lavin_ghost
# 964       964   1987  965                                chirandom | teamred
# 965       965   1987  966                                chirandom | teamred
# 966       966   1988  967                                 teamred | chiscifi
# 967       967   1988  968  chifantasy | teamblack | pbgothic | stew | lav...
# 968       968   1988  969                             chifantasy | teamblack
# 969       969   1988  970                         teamblack | chimyst | stew
# 970       970   1988  971                    teamred | chifantasy | chiscifi
# 971       971   1988  972             chirandom | teamblack | chimyst | stew
# 972       972   1989  973                                  teamred | chimyst
# 973       973   1989  974                    chirandom | teamblack | chimyst
# 974       974   1989  975                                  teamred | chimyst
# 975       975   1989  976                       teamblack | chihorror | stew
# 976       976   1989  977            chirandom | teamblack | chiscifi | stew
# 977       977   1989  978              teamred | chihorror | chiscifi | stew
# 978       978   1989  979                    teamred | chifantasy | chiscifi
# 979       979   1989  980  chifantasy | teamblack | chimyst | chihorror |...
# 980       980   1989  981               chirandom | teamred | chimyst | stew
# 981       981   1989  982                       teamred | chimyst | chiscifi
# 982       982   1989  983                              chirandom | teamblack
# 983       983   1989  984                                 teamred | chiscifi
#
#                                        titles                        authors  \
# 0                       The+savages+of+Europe    Lesuire%2C+Robert+Martin%2C
# 1                 Eloisa%3A+or+A+series+of+or    Rousseau%2C+Jean-Jacques%2C
# 2                 The+memoirs+of+Miss+D%27Arv                     Anonymous4
# 3                    The+castle+of+Otranto%3B           Walpole%2C+Horace%2C
# 4                   Memoirs+of+the+year+two+t   Mercier%2C+Louis-Sbastien%2C
# 5                   Letters+from+Henrietta+to                     Henrietta.
# 976                              Power+hungry         Weinstein%2C+Howard%2C
# 977                                  Mutation               Cook%2C+Robin%2C
# 978                  The+stress+of+her+regard               Powers%2C+Tim%2C
# 979                             Burning+water          Lackey%2C+Mercedes%2C
# 980                           Pious+deception             Dunlap%2C+Susan%2C
# 981                                    TekWar          Shatner%2C+William%2C
# 982                          Some+can+whistle           McMurtry%2C+Larry%2C
# 983                       Farewell+horizontal               Jeter%2C+K.+W%2C
#
#        lavin_genres big_genres  labels
# 0      no_lavin_tag  non_genre       7
# 1      no_lavin_tag  non_genre       3
# 2      no_lavin_tag  non_genre       3
# 3       lavin_ghost     gothic       7
# 4      no_lavin_tag      scifi       7
# 5      no_lavin_tag  non_genre       3
# 6       lavin_ghost     gothic       3
# 7      no_lavin_tag  non_genre       3
# 8      no_lavin_tag  non_genre       3
# 9      no_lavin_tag  non_genre       3
# 10   lavin_deranged     gothic       3
# 11     no_lavin_tag  non_genre       3
# 12      lavin_magic     gothic       7
# 13     no_lavin_tag  non_genre       3
# 14   lavin_deranged     gothic       3
# 15   lavin_deranged     gothic       3
# 16     no_lavin_tag  non_genre       7
# 17   lavin_deranged     gothic       7
# 18     no_lavin_tag  non_genre       7
# 19   lavin_deranged     gothic       7
# 20     no_lavin_tag  non_genre       3
# 21     no_lavin_tag     gothic       3
# 22   lavin_deranged     gothic       7
# 23   lavin_deranged     gothic       3
# 24     no_lavin_tag  non_genre       7
# 25     no_lavin_tag  non_genre       3
# 26     no_lavin_tag     gothic       7
# 27     no_lavin_tag     gothic       7
# 28     no_lavin_tag  non_genre       3
# 29     no_lavin_tag  non_genre       3
# ..              ...        ...     ...
# 954    no_lavin_tag      crime       4
# 955    no_lavin_tag      scifi       4
# 956    no_lavin_tag      scifi       5
# 957    no_lavin_tag      crime       4
# 958    no_lavin_tag  non_genre       0
# 959     lavin_multi     gothic       0
# 960    no_lavin_tag  non_genre       0
# 961    no_lavin_tag      crime       0
# 962    no_lavin_tag  non_genre       2
# 963     lavin_ghost     gothic       2
# 964    no_lavin_tag  non_genre       0
# 965    no_lavin_tag  non_genre       0
# 966    no_lavin_tag      scifi       4
# 967     lavin_magic     gothic       2
# 968    no_lavin_tag  non_genre       4
# 969    no_lavin_tag      crime       0
# 970    no_lavin_tag      scifi       4
# 971    no_lavin_tag      crime       4
# 972    no_lavin_tag      crime       0
# 973    no_lavin_tag      crime       0
# 974    no_lavin_tag      crime       4
# 975    no_lavin_tag     gothic       2
# 976    no_lavin_tag      scifi       4
# 977    no_lavin_tag      multi       0
# 978    no_lavin_tag      scifi       0
# 979     lavin_multi      multi       2
# 980    no_lavin_tag      crime       2
# 981    no_lavin_tag      multi       0
# 982    no_lavin_tag  non_genre       0
# 983    no_lavin_tag      scifi       4
#
# [984 rows x 9 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

lw = 2

fig = plt.figure(figsize=(16,7))

plt.scatter(_df["x"], _df["y"], c=_df["year"], s=55, lw=lw)

plt.title('PCA of 8040 Features')
#fig.savefig("viz/PCA_8040_by_year.png")
plt.show()
